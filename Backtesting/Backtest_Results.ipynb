# %% [markdown]
# # Backtest Analysis - Long-Short Equity Average Sentiment Algorithm

# %%
bt = get_backtest('5a1971b0a7a94b4499ca39ff')
bt.create_full_tear_sheet()
# Out:
# 100% Time: 0:00:07|###########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2014-06-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2017-10-25</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>40</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>11.0%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>42.5%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>8.1%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.33</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.35</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
# ...
